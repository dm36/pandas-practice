# %%
import pandas as pd

# %%
# Index generated automatically, 30 rows at the top, 30 at the bottom, age and weight defaults to floating point
# values
nba = pd.read_csv("nba.csv")
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.Team.value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Denver Nuggets            15
# Charlotte Hornets         15
# Los Angeles Lakers        15
# Chicago Bulls             15
# San Antonio Spurs         15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Detroit Pistons           15
# Boston Celtics            15
# Miami Heat                15
# Utah Jazz                 15
# Portland Trail Blazers    15
# Los Angeles Clippers      15
# Phoenix Suns              15
# Golden State Warriors     15
# Cleveland Cavaliers       15
# Washington Wizards        15
# Atlanta Hawks             15
# Brooklyn Nets             15
# Houston Rockets           15
# Dallas Mavericks          15
# Sacramento Kings          15
# Indiana Pacers            15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba[nba["Team"] == "Golden State Warriors"]
# Out:
#                     Name                   Team  Number Position   Age Height  \
# 76       Leandro Barbosa  Golden State Warriors    19.0       SG  33.0    6-3
# 77       Harrison Barnes  Golden State Warriors    40.0       SF  24.0    6-8
# 78          Andrew Bogut  Golden State Warriors    12.0        C  31.0    7-0
# 79             Ian Clark  Golden State Warriors    21.0       SG  25.0    6-3
# 80         Stephen Curry  Golden State Warriors    30.0       PG  28.0    6-3
# 81          Festus Ezeli  Golden State Warriors    31.0        C  26.0   6-11
# 82        Draymond Green  Golden State Warriors    23.0       PF  26.0    6-7
# 83        Andre Iguodala  Golden State Warriors     9.0       SF  32.0    6-6
# 84      Shaun Livingston  Golden State Warriors    34.0       PG  30.0    6-7
# 85          Kevon Looney  Golden State Warriors    36.0       SF  20.0    6-9
# 86  James Michael McAdoo  Golden State Warriors    20.0       SF  23.0    6-9
# ...

# %% [markdown]
# # Shared Methods and Attributes

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Number of rows
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
# Array of arrays
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
# Python tuple rows by columns
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Array of column names
nba.columns
# Out:
# Index([u'Name', u'Team', u'Number', u'Position', u'Age', u'Height', u'Weight',
#        u'College', u'Salary'],
#       dtype='object')

# %%
# Index combines it with columns
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index([u'Name', u'Team', u'Number', u'Position', u'Age', u'Height', u'Weight',
#         u'College', u'Salary'],
#        dtype='object')]

# %%
# Summary of a df- 4 are float64, 5 are objects- can see some salaries are missing, not available on a series
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# Series- index is datatypes value is # with that datatypes- take away is that there are unique attributes and methods to both, memorize through
# practice and experience
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# # Differences between Shared Methods

# %%
# Sum behaves differently in series and data frames
pd.read_csv("revenue.csv")
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/16       985          122    499
# 1   1/2/16       738          788    534
# 2   1/3/16        14           20    933
# 3   1/4/16       730          904    885
# 4   1/5/16       114           71    253
# 5   1/6/16       936          502    497
# 6   1/7/16       123          996    115
# 7   1/8/16       935          492    886
# 8   1/9/16       846          954    823
# 9  1/10/16        54          285    216

# %%
rev = pd.read_csv("revenue.csv", index_col='Date')

# %%
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1, 2, 3])
s
s.sum()
# Out:
# 6

# %%
s.sum(axis = '1')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-26-a23d214bd38f> in <module>()
# ----> 1 s.sum(axis = '1')
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9567                                       skipna=skipna, min_count=min_count)
#    9568         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9569                             numeric_only=numeric_only, min_count=min_count)
#    9570
#    9571     return set_function_name(stat_func, name, cls)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3211         if isinstance(delegate, np.ndarray):
#    3212             # Validate that 'axis' is consistent with Series's single axis.
# -> 3213             self._get_axis_number(axis)
#    3214             if numeric_only:
# ...

# %%
# Columns and the sum of all the values for that column
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
# Sum by date, axis = 0, get the same result, axis = 'index' same result
rev.sum(axis = 1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# # Select One Column from a DataFrame

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Extract a column from a DF we get a series- takes index from the DF
nba.Name
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
# 5      90.0
# 6      55.0
# 7      41.0
# 8      12.0
# 9      36.0
# 10      7.0
# 11      4.0
# 12     11.0
# 13     13.0
# 14     44.0
# 15     44.0
# 16     22.0
# 17     21.0
# 18     24.0
# 19      2.0
# 20     10.0
# 21      6.0
# 22      0.0
# 23     11.0
# 24      1.0
# 25     33.0
# 26     41.0
# 27     14.0
# 28     15.0
# 29     30.0
#        ...
# 428     8.0
# 429     5.0
# 430    23.0
# 431    17.0
# 432     4.0
# 433     9.0
# 434    35.0
# 435    11.0
# 436     0.0
# 437     3.0
# 438    44.0
# 439    24.0
# 440     2.0
# 441    21.0
# 442    33.0
# 443     3.0
# 444    10.0
# 445    11.0
# 446    15.0
# 447    27.0
# 448    20.0
# 449     5.0
# 450     2.0
# 451    23.0
# 452    41.0
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
# Case sensitive
nba.salary
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-35-add4fe754f93> in <module>()
# ----> 1 nba.salary
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'salary'

# %%
# Save us some space- this syntax only works when the column name doesn't have spaces
nba.Salary
Output = None

# %%
nba["Name"]
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
type(nba["Salary"])
# Out:
# pandas.core.series.Series

# %%
nba["Name"].head(5)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %% [markdown]
# # Select Two or More Columns from a Dataframe

# %%
# Pass a Python list
nba[["Name", "Number", "Salary"]]
# Out:
#                         Name  Number      Salary
# 0              Avery Bradley     0.0   7730337.0
# 1                Jae Crowder    99.0   6796117.0
# 2               John Holland    30.0         NaN
# 3                R.J. Hunter    28.0   1148640.0
# 4              Jonas Jerebko     8.0   5000000.0
# 5               Amir Johnson    90.0  12000000.0
# 6              Jordan Mickey    55.0   1170960.0
# 7               Kelly Olynyk    41.0   2165160.0
# 8               Terry Rozier    12.0   1824360.0
# 9               Marcus Smart    36.0   3431040.0
# 10           Jared Sullinger     7.0   2569260.0
# 11             Isaiah Thomas     4.0   6912869.0
# 12               Evan Turner    11.0   3425510.0
# 13               James Young    13.0   1749840.0
# 14              Tyler Zeller    44.0   2616975.0
# 15          Bojan Bogdanovic    44.0   3425510.0
# 16              Markel Brown    22.0    845059.0
# 17           Wayne Ellington    21.0   1500000.0
# ...

# %%
type(nba[["Name", "Team"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Can reorder at will
nba[["Team", "Name"]]
# Out:
#                        Team                     Name
# 0            Boston Celtics            Avery Bradley
# 1            Boston Celtics              Jae Crowder
# 2            Boston Celtics             John Holland
# 3            Boston Celtics              R.J. Hunter
# 4            Boston Celtics            Jonas Jerebko
# 5            Boston Celtics             Amir Johnson
# 6            Boston Celtics            Jordan Mickey
# 7            Boston Celtics             Kelly Olynyk
# 8            Boston Celtics             Terry Rozier
# 9            Boston Celtics             Marcus Smart
# 10           Boston Celtics          Jared Sullinger
# 11           Boston Celtics            Isaiah Thomas
# 12           Boston Celtics              Evan Turner
# 13           Boston Celtics              James Young
# 14           Boston Celtics             Tyler Zeller
# 15            Brooklyn Nets         Bojan Bogdanovic
# 16            Brooklyn Nets             Markel Brown
# ...

# %%
nba[["Team", "Name"]].head(3)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland

# %%
nba[["Number", "College"]]
# Out:
#      Number            College
# 0       0.0              Texas
# 1      99.0          Marquette
# 2      30.0  Boston University
# 3      28.0      Georgia State
# 4       8.0                NaN
# 5      90.0                NaN
# 6      55.0                LSU
# 7      41.0            Gonzaga
# 8      12.0         Louisville
# 9      36.0     Oklahoma State
# 10      7.0         Ohio State
# 11      4.0         Washington
# 12     11.0         Ohio State
# 13     13.0           Kentucky
# 14     44.0     North Carolina
# 15     44.0                NaN
# 16     22.0     Oklahoma State
# 17     21.0     North Carolina
# 18     24.0            Arizona
# 19      2.0       Georgia Tech
# 20     10.0                NaN
# 21      6.0         Cincinnati
# 22      0.0         Miami (FL)
# 23     11.0           Stanford
# 24      1.0           Syracuse
# 25     33.0        Saint Louis
# 26     41.0             Kansas
# 27     14.0         Georgetown
# 28     15.0          Texas A&M
# ...

# %%
nba[["Salary", "Team", "Name"]].tail()
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
# Can also pass the list as such- syntax is cleaner don't have two bracketsf
select = ["Salary", "Team", "Name"]

# %%
nba[select]
# Out:
#          Salary                    Team                     Name
# 0     7730337.0          Boston Celtics            Avery Bradley
# 1     6796117.0          Boston Celtics              Jae Crowder
# 2           NaN          Boston Celtics             John Holland
# 3     1148640.0          Boston Celtics              R.J. Hunter
# 4     5000000.0          Boston Celtics            Jonas Jerebko
# 5    12000000.0          Boston Celtics             Amir Johnson
# 6     1170960.0          Boston Celtics            Jordan Mickey
# 7     2165160.0          Boston Celtics             Kelly Olynyk
# 8     1824360.0          Boston Celtics             Terry Rozier
# 9     3431040.0          Boston Celtics             Marcus Smart
# 10    2569260.0          Boston Celtics          Jared Sullinger
# 11    6912869.0          Boston Celtics            Isaiah Thomas
# 12    3425510.0          Boston Celtics              Evan Turner
# ...

# %% [markdown]
# # Adding New Column to DataFrame

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Scalar- can also give a series
nba["Sport"] = "Basketball"

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"] = "NBA"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport League
# 0              Texas  7730337.0  Basketball    NBA
# 1          Marquette  6796117.0  Basketball    NBA
# 2  Boston University        NaN  Basketball    NBA

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Don't need to use in-place parameter 
nba.insert(3, column = "Sport", value = "Basketball")

# %%
nba
# Out:
#                         Name                    Team  Number       Sport  \
# 0              Avery Bradley          Boston Celtics     0.0  Basketball
# 1                Jae Crowder          Boston Celtics    99.0  Basketball
# 2               John Holland          Boston Celtics    30.0  Basketball
# 3                R.J. Hunter          Boston Celtics    28.0  Basketball
# 4              Jonas Jerebko          Boston Celtics     8.0  Basketball
# 5               Amir Johnson          Boston Celtics    90.0  Basketball
# 6              Jordan Mickey          Boston Celtics    55.0  Basketball
# 7               Kelly Olynyk          Boston Celtics    41.0  Basketball
# 8               Terry Rozier          Boston Celtics    12.0  Basketball
# 9               Marcus Smart          Boston Celtics    36.0  Basketball
# 10           Jared Sullinger          Boston Celtics     7.0  Basketball
# 11             Isaiah Thomas          Boston Celtics     4.0  Basketball
# ...

# %%
# First parameter is the position, second  is the new column name and the last is the value
nba.insert(7, column = "League", value = "NBA")

# %%
nba
# Out:
#                         Name                    Team  Number       Sport  \
# 0              Avery Bradley          Boston Celtics     0.0  Basketball
# 1                Jae Crowder          Boston Celtics    99.0  Basketball
# 2               John Holland          Boston Celtics    30.0  Basketball
# 3                R.J. Hunter          Boston Celtics    28.0  Basketball
# 4              Jonas Jerebko          Boston Celtics     8.0  Basketball
# 5               Amir Johnson          Boston Celtics    90.0  Basketball
# 6              Jordan Mickey          Boston Celtics    55.0  Basketball
# 7               Kelly Olynyk          Boston Celtics    41.0  Basketball
# 8               Terry Rozier          Boston Celtics    12.0  Basketball
# 9               Marcus Smart          Boston Celtics    36.0  Basketball
# 10           Jared Sullinger          Boston Celtics     7.0  Basketball
# 11             Isaiah Thomas          Boston Celtics     4.0  Basketball
# ...

# %% [markdown]
# # Broadcasting Operations

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Add 5 to every value in the age column
nba["Age"].add(5)
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Age"] + 5
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"].sub(5000000)
# Out:
# 0       2730337.0
# 1       1796117.0
# 2             NaN
# 3      -3851360.0
# 4             0.0
# 5       7000000.0
# 6      -3829040.0
# 7      -2834840.0
# 8      -3175640.0
# 9      -1568960.0
# 10     -2430740.0
# 11      1912869.0
# 12     -1574490.0
# 13     -3250160.0
# 14     -2383025.0
# 15     -1574490.0
# 16     -4154941.0
# 17     -3500000.0
# 18     -3664520.0
# 19      1300000.0
# 20     -3400160.0
# 21     -4865785.0
# 22     -3500000.0
# 23     14689000.0
# 24     -3859760.0
# 25     -4052724.0
# 26     -4018652.0
# 27     -4052724.0
# 28     -4052724.0
# 29      6235955.0
#           ...
# 428     3042895.0
# 429    -4374907.0
# 430    -4052724.0
# 431     1980802.0
# 432    -2105941.0
# 433     1000000.0
# 434       16000.0
# 435    -1924120.0
# 436     -763713.0
# 437    -2474840.0
# 438    -4474907.0
# 439    -3584480.0
# 440    -2145060.0
# 441    -2362280.0
# 442     -225000.0
# 443    -2341760.0
# 444     4463484.0
# 445    -1222280.0
# 446     7000000.0
# ...

# %%
nba['Salary'] - 5000000
# Out:
# 0       2730337.0
# 1       1796117.0
# 2             NaN
# 3      -3851360.0
# 4             0.0
# 5       7000000.0
# 6      -3829040.0
# 7      -2834840.0
# 8      -3175640.0
# 9      -1568960.0
# 10     -2430740.0
# 11      1912869.0
# 12     -1574490.0
# 13     -3250160.0
# 14     -2383025.0
# 15     -1574490.0
# 16     -4154941.0
# 17     -3500000.0
# 18     -3664520.0
# 19      1300000.0
# 20     -3400160.0
# 21     -4865785.0
# 22     -3500000.0
# 23     14689000.0
# 24     -3859760.0
# 25     -4052724.0
# 26     -4018652.0
# 27     -4052724.0
# 28     -4052724.0
# 29      6235955.0
#           ...
# 428     3042895.0
# 429    -4374907.0
# 430    -4052724.0
# 431     1980802.0
# 432    -2105941.0
# 433     1000000.0
# 434       16000.0
# 435    -1924120.0
# 436     -763713.0
# 437    -2474840.0
# 438    -4474907.0
# 439    -3584480.0
# 440    -2145060.0
# 441    -2362280.0
# 442     -225000.0
# 443    -2341760.0
# 444     4463484.0
# 445    -1222280.0
# 446     7000000.0
# ...

# %%
# Weight in kg
nba["Weight"].mul(0.453592)
# Out:
# 0       81.646560
# 1      106.594120
# 2       92.986360
# 3       83.914520
# 4      104.779752
# 5      108.862080
# 6      106.594120
# 7      107.954896
# 8       86.182480
# 9       99.790240
# 10     117.933920
# 11      83.914520
# 12      99.790240
# 13      97.522280
# 14     114.758776
# 15      97.975872
# 16      86.182480
# 17      90.718400
# 18      99.790240
# 19      90.718400
# 20      94.347136
# 21      99.336648
# 22      79.378600
# 23     124.737800
# 24      90.718400
# 25      99.790240
# 26     107.501304
# 27     112.490816
# 28      92.986360
# 29     100.243832
#           ...
# 428     97.522280
# 429     93.439952
# 430     95.254320
# 431    108.862080
# 432     97.522280
# 433     97.522280
# 434    120.201880
# 435    111.130040
# 436     88.450440
# 437     90.718400
# 438     83.914520
# 439    106.594120
# 440     78.471416
# 441    108.862080
# 442    103.418976
# 443     86.636072
# 444     97.068688
# 445     86.182480
# 446    120.201880
# ...

# %%
nba["Weight"]
# Out:
# 0      180.0
# 1      235.0
# 2      205.0
# 3      185.0
# 4      231.0
# 5      240.0
# 6      235.0
# 7      238.0
# 8      190.0
# 9      220.0
# 10     260.0
# 11     185.0
# 12     220.0
# 13     215.0
# 14     253.0
# 15     216.0
# 16     190.0
# 17     200.0
# 18     220.0
# 19     200.0
# 20     208.0
# 21     219.0
# 22     175.0
# 23     275.0
# 24     200.0
# 25     220.0
# 26     237.0
# 27     248.0
# 28     205.0
# 29     221.0
#        ...
# 428    215.0
# 429    206.0
# 430    210.0
# 431    240.0
# 432    215.0
# 433    215.0
# 434    265.0
# 435    245.0
# 436    195.0
# 437    200.0
# 438    185.0
# 439    235.0
# 440    173.0
# 441    240.0
# 442    228.0
# 443    191.0
# 444    214.0
# 445    190.0
# 446    265.0
# 447    245.0
# 448    226.0
# 449    206.0
# 450    226.0
# 451    206.0
# 452    234.0
# 453    203.0
# 454    179.0
# 455    256.0
# 456    231.0
# 457      NaN
# Name: Weight, Length: 458, dtype: float64

# %%
nba["Weight in Kg"] = nba["Weight"] * 0.45392

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kg
# 0              Texas  7730337.0       81.7056
# 1          Marquette  6796117.0      106.6712
# 2  Boston University        NaN       93.0536

# %%
nba["Salary"].div(1000000)
# Out:
# 0       7.730337
# 1       6.796117
# 2            NaN
# 3       1.148640
# 4       5.000000
# 5      12.000000
# 6       1.170960
# 7       2.165160
# 8       1.824360
# 9       3.431040
# 10      2.569260
# 11      6.912869
# 12      3.425510
# 13      1.749840
# 14      2.616975
# 15      3.425510
# 16      0.845059
# 17      1.500000
# 18      1.335480
# 19      6.300000
# 20      1.599840
# 21      0.134215
# 22      1.500000
# 23     19.689000
# 24      1.140240
# 25      0.947276
# 26      0.981348
# 27      0.947276
# 28      0.947276
# 29     11.235955
#          ...
# 428     8.042895
# 429     0.625093
# 430     0.947276
# 431     6.980802
# 432     2.894059
# 433     6.000000
# 434     5.016000
# 435     3.075880
# 436     4.236287
# 437     2.525160
# 438     0.525093
# 439     1.415520
# 440     2.854940
# 441     2.637720
# 442     4.775000
# 443     2.658240
# 444     9.463484
# 445     3.777720
# 446    12.000000
# 447     1.175880
# 448    15.409570
# ...

# %%
nba["Salary in Millions"] = nba["Salary"] / 1000000

# %%
nba["Salary in Millions"]
# Out:
# 0       7.730337
# 1       6.796117
# 2            NaN
# 3       1.148640
# 4       5.000000
# 5      12.000000
# 6       1.170960
# 7       2.165160
# 8       1.824360
# 9       3.431040
# 10      2.569260
# 11      6.912869
# 12      3.425510
# 13      1.749840
# 14      2.616975
# 15      3.425510
# 16      0.845059
# 17      1.500000
# 18      1.335480
# 19      6.300000
# 20      1.599840
# 21      0.134215
# 22      1.500000
# 23     19.689000
# 24      1.140240
# 25      0.947276
# 26      0.981348
# 27      0.947276
# 28      0.947276
# 29     11.235955
#          ...
# 428     8.042895
# 429     0.625093
# 430     0.947276
# 431     6.980802
# 432     2.894059
# 433     6.000000
# 434     5.016000
# 435     3.075880
# 436     4.236287
# 437     2.525160
# 438     0.525093
# 439     1.415520
# 440     2.854940
# 441     2.637720
# 442     4.775000
# 443     2.658240
# 444     9.463484
# 445     3.777720
# 446    12.000000
# 447     1.175880
# 448    15.409570
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kg  Salary in Millions
# 0              Texas  7730337.0       81.7056            7.730337
# 1          Marquette  6796117.0      106.6712            6.796117
# 2  Boston University        NaN       93.0536                 NaN

# %% [markdown]
# # A Review of the Value Counts Method

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Denver Nuggets            15
# Charlotte Hornets         15
# Los Angeles Lakers        15
# Chicago Bulls             15
# San Antonio Spurs         15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Detroit Pistons           15
# Boston Celtics            15
# Miami Heat                15
# Utah Jazz                 15
# Portland Trail Blazers    15
# Los Angeles Clippers      15
# Phoenix Suns              15
# Golden State Warriors     15
# Cleveland Cavaliers       15
# Washington Wizards        15
# Atlanta Hawks             15
# Brooklyn Nets             15
# Houston Rockets           15
# Dallas Mavericks          15
# Sacramento Kings          15
# Indiana Pacers            15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts().head(1)
# Out:
# SG    102
# Name: Position, dtype: int64

# %%
nba["Weight"].value_counts().tail()
# Out:
# 278.0    1
# 227.0    1
# 239.0    1
# 289.0    1
# 307.0    1
# Name: Weight, dtype: int64

# %%
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 1100602.0      5
# 16407500.0     5
# 5000000.0      5
# 12000000.0     5
# 8000000.0      5
# 4000000.0      5
# 3000000.0      4
# 7000000.0      4
# 2814000.0      4
# 1000000.0      4
# 19689000.0     4
# 200600.0       3
# 8500000.0      3
# 2500000.0      3
# 1015421.0      3
# 2854940.0      3
# 13500000.0     3
# 5543725.0      3
# 2288205.0      2
# 1270964.0      2
# 2900000.0      2
# 1007026.0      2
# 111444.0       2
# 13000000.0     2
# 1500000.0      2
# 1842000.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# ...

# %% [markdown]
# # Drop Rows with Null Values

# %%
# Drop any rows where there is one or more null values
nbadropped = nba.dropna()

# %%
nba[nba["Name"] == "John Holland"]
# Out:
#            Name            Team  Number Position   Age Height  Weight  \
# 2  John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College  Salary  Weight in Kg  Salary in Millions
# 2  Boston University     NaN       93.0536                 NaN

# %%
nbadropped[nbadropped["Name"] == "John Holland"]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary, Weight in Kg, Salary in Millions]
# Index: []

# %%
# Now drops if all of the values are null
nba.dropna(how = "all")
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.dropna(how = "all", inplace = True)

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary  Weight in Kg  Salary in Millions
# 454   900000.0      81.25168            0.900000
# 455  2900000.0     116.20352            2.900000
# 456   947276.0     104.85552            0.947276

# %%
# Remove columns where there are null values rather than rows
nba.dropna(axis = 1)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.dropna(axis = "columns")
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kg  Salary in Millions
# 0              Texas  7730337.0       81.7056            7.730337
# 1          Marquette  6796117.0      106.6712            6.796117
# 2  Boston University        NaN       93.0536                 NaN

# %%
# Only going to drop rows that have a null in the salary column
nba.dropna(subset = ["Salary", "College"])
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# ...

# %% [markdown]
# # Fill in null values with the .fillna() method

# %%
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba["Salary"].fillna(0, inplace=True)

# %%
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 0.0           11
# 981348.0       6
# 4000000.0      5
# 1100602.0      5
# 5000000.0      5
# 8000000.0      5
# 12000000.0     5
# 16407500.0     5
# 7000000.0      4
# 1000000.0      4
# 19689000.0     4
# 2814000.0      4
# 3000000.0      4
# 8500000.0      3
# 2500000.0      3
# 200600.0       3
# 1015421.0      3
# 13500000.0     3
# 5543725.0      3
# 2854940.0      3
# 1842000.0      2
# 55722.0        2
# 11235955.0     2
# 5500000.0      2
# 1140240.0      2
# 13000000.0     2
# 2170465.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# ...

# %%
nba["College"].fillna("No College", inplace = True)

# %%
nba["College"].value_counts()
# Out:
# No college             84
# Kentucky               22
# Duke                   20
# Kansas                 18
# North Carolina         16
# UCLA                   15
# Arizona                13
# Florida                10
# Texas                   9
# Syracuse                8
# USC                     7
# Connecticut             7
# Washington              7
# LSU                     6
# Wake Forest             6
# Michigan State          6
# Georgia Tech            6
# Georgetown              6
# Michigan                6
# Ohio State              5
# Wisconsin               5
# Marquette               5
# Stanford                5
# UNLV                    4
# Villanova               4
# Oklahoma State          4
# Indiana                 4
# Tennessee               4
# California              3
# Nevada                  3
#                        ..
# Iowa State              1
# Houston                 1
# Western Michigan        1
# Detroit                 1
# ...

# %% [markdown]
# # The .asType() Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba["College"].fillna("None", inplace = True)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
# Convert salary from floats to integers- no in place param
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %%
nba["Age"] = nba["Age"].astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 35.7+ KB

# %%
nba["Number"] = nba["Number"].astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null object
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 35.7+ KB

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
# Categories to save memory
nba["Position"] = nba["Position"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(1), float64(1), int64(3), object(4)
# memory usage: 32.8+ KB

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba["Team"]
# Out:
# 0              Boston Celtics
# 1              Boston Celtics
# 2              Boston Celtics
# 3              Boston Celtics
# 4              Boston Celtics
# 5              Boston Celtics
# 6              Boston Celtics
# 7              Boston Celtics
# 8              Boston Celtics
# 9              Boston Celtics
# 10             Boston Celtics
# 11             Boston Celtics
# 12             Boston Celtics
# 13             Boston Celtics
# 14             Boston Celtics
# 15              Brooklyn Nets
# 16              Brooklyn Nets
# 17              Brooklyn Nets
# 18              Brooklyn Nets
# 19              Brooklyn Nets
# 20              Brooklyn Nets
# 21              Brooklyn Nets
# 22              Brooklyn Nets
# 23              Brooklyn Nets
# 24              Brooklyn Nets
# 25              Brooklyn Nets
# 26              Brooklyn Nets
# 27              Brooklyn Nets
# 28              Brooklyn Nets
# 29              Brooklyn Nets
#                 ...
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(2), float64(1), int64(3), object(3)
# memory usage: 31.1+ KB

# %% [markdown]
# # Sort a DataFrame with the .sort_values() Method, Part I

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.sort_values("Team")
# Out:
#                  Name                Team  Number Position   Age Height  \
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 313    Kris Humphries       Atlanta Hawks    43.0       PF  31.0    6-9
# 314       Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 316      Mike Muscala       Atlanta Hawks    31.0       PF  24.0   6-11
# 318   Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0    6-8
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# ...

# %%
nba.sort_values("Name", ascending = False)
# Out:
#                     Name                    Team  Number Position   Age  \
# 237        Zaza Pachulia        Dallas Mavericks    27.0        C  32.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 270       Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 385          Will Barton          Denver Nuggets     5.0       SF  25.0
# 233      Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 97        Wesley Johnson    Los Angeles Clippers    33.0       SF  28.0
# 17       Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 322       Walter Tavares           Atlanta Hawks    22.0        C  24.0
# ...

# %%
nba.sort_values("Age")
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 40   Kristaps Porzingis         New York Knicks     6.0       PF  20.0    7-3
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8
# 116    D'Angelo Russell      Los Angeles Lakers     1.0       PG  20.0    6-5
# 441         Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 356        Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 56        Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# 445          Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 377     Kelly Oubre Jr.      Washington Wizards    12.0       SF  20.0    6-7
# ...

# %%
nba.sort_values("Age", ascending = False)
# Out:
#                       Name                    Team  Number Position   Age  \
# 304           Andre Miller       San Antonio Spurs    24.0       PG  40.0
# 400          Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0
# 298             Tim Duncan       San Antonio Spurs    21.0        C  40.0
# 261           Vince Carter       Memphis Grizzlies    15.0       SG  39.0
# 102         Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0
# 299          Manu Ginobili       San Antonio Spurs    20.0       SG  38.0
# 101            Paul Pierce    Los Angeles Clippers    34.0       SF  38.0
# 256            Jason Terry         Houston Rockets    31.0       SG  38.0
# 420          Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0
# 236          Dirk Nowitzki        Dallas Mavericks    41.0       PF  37.0
# 46             Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 259         Chris Andersen       Memphis Grizzlies     7.0       PF  37.0
# ...

# %%
nba.sort_values("Salary", ascending = False, inplace = True)

# %%
nba
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# ...

# %%
nba[nba.College == "Duke"]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 168      Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0    6-3
# 340         Luol Deng              Miami Heat     9.0       SF  31.0    6-9
# 103         JJ Redick    Los Angeles Clippers     4.0       SG  31.0    6-4
# 433  Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# 346    Josh McRoberts              Miami Heat     4.0       PF  29.0   6-10
# 223     Jabari Parker         Milwaukee Bucks    12.0       PF  21.0    6-8
# 56      Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# 154     Mike Dunleavy           Chicago Bulls    34.0       SG  35.0    6-9
# 424      Kyle Singler   Oklahoma City Thunder     5.0       SF  28.0    6-8
# 104     Austin Rivers    Los Angeles Clippers    25.0       PG  23.0    6-4
# 352   Justise Winslow              Miami Heat    20.0       SF  20.0    6-7
# ...

# %%
nba.sort_values("Salary", ascending = "False", na_position = "first")
# Out:
#                        Name                    Team  Number Position   Age  \
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# ...

# %% [markdown]
# # Sort a DataFrame with the .sort_values() Method, Part II

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Sorted alphabetically within each team- team is ascending, name in reverse-alphabetical
nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)

# %%
nba.head(3)
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
#
#       College     Salary
# 322       NaN  1000000.0
# 310  Michigan  1304520.0
# 321       NaN  9756250.0

# %% [markdown]
# # Sort a DataFrame with the .sort_index Method

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace = True)

# %%
nba.sort_index(ascending = False, inplace = True)

# %%
nba.head(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0
# 454   900000.0
# 453  2433333.0

# %% [markdown]
# # Rank Values with the .rank() Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba["Salary"] = nba["Salary"].fillna(0).astype(int)
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype(int)

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values("Salary Rank")
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# ...

# %%
nba.sort_values("Salary", ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# ...

# %%
nba[nba.Team == "Golden State Warriors"].sort_values("Salary", ascending = False)
# Out:
#                     Name                   Team  Number Position   Age Height  \
# 89         Klay Thompson  Golden State Warriors    11.0       SG  26.0    6-7
# 82        Draymond Green  Golden State Warriors    23.0       PF  26.0    6-7
# 78          Andrew Bogut  Golden State Warriors    12.0        C  31.0    7-0
# 83        Andre Iguodala  Golden State Warriors     9.0       SF  32.0    6-6
# 80         Stephen Curry  Golden State Warriors    30.0       PG  28.0    6-3
# 84      Shaun Livingston  Golden State Warriors    34.0       PG  30.0    6-7
# 77       Harrison Barnes  Golden State Warriors    40.0       SF  24.0    6-8
# 88     Marreese Speights  Golden State Warriors     5.0        C  28.0   6-10
# 76       Leandro Barbosa  Golden State Warriors    19.0       SG  33.0    6-3
# 81          Festus Ezeli  Golden State Warriors    31.0        C  26.0   6-11
# 87          Brandon Rush  Golden State Warriors     4.0       SF  30.0    6-6
# ...
